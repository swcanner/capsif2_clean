# %% [markdown]
# # CAPSIF Prediction on a directory #
#
# ### Input your directories below - same as seen in `predict_directory.py` ###
# ### Results outputted to __`[out_dir]/*.pdb`__ with predictions and the file __`[out_dir]/capsif_predictions.txt`__ ###
#
# ## Current settings for B Factor visualization: ##
# #### `BFactor =  0.0` : Nonbinder ####
# #### `BFactor = 40.0` : CAPSIF:G Predicted Binder ####
# #### `BFactor = 59.9` : CAPSIF:V Predicted Binder ####
# #### `BFactor = 99.9` : CAPSIF:V and CAPSIF:G Predicted Binder ####

# %% [markdown]
# ## Changeable Parameters ##
#
# `input_dir` - input directory of pdbs for prediction
#
# `out_dir` - output directory of predictions
#
# `graph_model_dir` - graph model of choice
#
# `voxel_model_dir` - voxel model of choice
#
# `make_pdb` - whether or not to output the pdb's for visualization

# %% [markdown]
# ## Change the input values then RUN ALL to get your results!!! ##

# %%
#download the bois

import pandas as pd
from Bio.PDB import *

# %%
aa_inv = {
    "H": "HIS",
    "K": "LYS",
    "R": "ARG",
    "D": "ASP",
    "E": "GLU",
    "S": "SER",
    "T": "THR",
    "N": "ASN",
    "Q": "GLN",
    "A": "ALA",
    "V": "VAL",
    "L": "LEU",
    "I": "ILE",
    "M": "MET",
    "F": "PHE",
    "Y": "TYR",
    "W": "TRP",
    "P": "PRO",
    "G": "GLY",
    "C": "CYS",
    "X": "MSE",
    "Z": "CYD"
}
aa_inv.keys()
prot_aa = aa_inv.values()

# %%
class ProtSelect(Select):
    def accept_residue(self, residue):
        r = residue
        #help(r)
        #if residue.get_resname()=='GLY':
        
        n = str(r.id[1]).strip()
        c = str(r.get_parent().id).strip()
        resname = str(r.get_resname())
        resarr = [n,c,resname]
        #if resname in carb:
        if resarr in res_p:
            return 1
        else:
            return 0

# %%
file = "/Users/scanner1/Downloads/T145_data.csv"
df = pd.read_csv(file)
#print(df.values)

# %%
for ii in df.values:
    p = ii[0]
    c = ii[1]
    print(p)
    try:
        pose = pose_from_pdb('temp_dir/' + p + '.pdb')
        info = pose.pdb_info()
        for r in range(pose.size(),1,-1):
            chain = info.pose2pdb(3).strip().split(' ')[-1]
            is_prot = pose.residue(r).is_protein()
            if chain not in c:
                if is_prot:
                    pose.delete_residue_slow(r);
        pose.dump_pdb('temp_dir/' + p + '_' + c + '.pdb')
            
        #break;
        
    except:
        print('nah')

# %%
for ii in df.values:
    #print(ii)
    #download_pdb(ii[0],data_dir='./temp_dir/',assembly=0)

# %%
for ii in df.values:
    #print(ii)
    download_pdb(ii[0],data_dir='./temp_dir/',assembly=0)

# %%
sz = pose.size()
r = pose.residue(3)

# %%
r.is_protein()
# Out:
# True

# %%
info = pose.pdb_info()

# %%
info.pose2pdb(3).strip().split(' ')
# Out:
# ['3', 'A']

# %%
ls = os.listdir('temp_dir/')

ape = []
for ii in df.values:
    p = ii[0]
    c = ii[1]
    print(p)
    try:
        pose = pose_from_pdb('temp_dir/' + p + '.pdb')
        info = pose.pdb_info()
        for r in range(pose.size(),1,-1):
            chain = info.pose2pdb(3).strip().split(' ')[-1]
            is_prot = pose.residue(r).is_protein()
            if chain not in c:
                if is_prot:
                    pose.delete_residue_slow(r);
        pose.dump_pdb('temp_dir/' + p + '_' + c + '.pdb')
            
        #break;
        
    except:
        print('nah')
# Out:
# 6LZQ
# 6M5Y
# 6STN
# 6TEC
# 6WQW
# 6WXA
# nah
# 6X3Q
# 6X7X
# nah
# 6XBO
# 6XHD
# 6XUU
# nah
# 6XZ2
# 6Y0U
# 6Y8F
# 6YM9
# 6Z61
# 6ZM9
# 6ZPA
# 6ZXQ
# 7B7C
# nah
# 7BLG
# 7BM6
# 7BNR
# 7BZ0
# 7C4C
# 7C6D
# 7CJ5
# nah
# 7CL0
# 7CNW
# nah
# 7CTM
# nah
# 7CWA
# 7D5G
# 7DC9
# 7DFS
# 7DSY
# 7E78
# 7EAP
# 7EBQ
# 7ECD
# 7EF7
# 7EIQ
# nah
# 7EJW
# 7ESN
# nah
# 7EXO
# nah
# 7F04
# 7F4P
# 7F6W
# 7F7C
# 7F9G
# 7JG0
# 7JNB
# nah
# 7JUC
# nah
# 7JVD
# 7K0A
# 7KMO
# nah
# 7KNC
# nah
# 7KW6
# 7KYD
# 7L1Y
# 7LAM
# 7LLD
# 7LSU
# 7LV3
# 7LW3
# 7LXI
# 7MIR
# 7MP9
# 7MZQ
# 7N7H
# 7NCZ
# 7NHO
# 7NWF
# 7O4G
# nah
# 7O4T
# 7O82
# 7OCQ
# 7ODX
# 7OMT
# 7OPQ
# 7OQX
# 7P04
# 7P9O
# 7PL1
# 7POD
# nah
# 7PUG
# 7PV6
# 7QEI
# 7QIF
# 7R0T
# 7RPH
# 7RPY
# 7RZB
# 7RZJ
# nah
# 7S3U
# 7SCD
# nah
# 7SEZ
# 7SP8
# 7SPT
# nah
# 7SSJ
# 7T27
# 7T7Q
# 7TGQ
# 7TOH
# 7TOM
# 7TPV
# 7TXP
# 7UFP
# 7V4S
# 7V6I
# 7V7X
# 7V8J
# 7VA2
# 7VCP
# nah
# 7VEU
# nah
# 7VNX
# 7VS7
# 7VT6
# 7VTL
# 7VWF
# 7VX8
# 7W13
# 7WAJ
# 7WDT
# 7WHU
# nah
# 7WJ7
# 7WW5
# 7XDQ
# 7XF7
# 7XK6
# 7Y4I
# 7Z0S
# 7Z15
# 7ZHB
# 7ZHZ
# nah
# 7ZKH
# 7ZY9
# 8AB3
# nah
# 8AS8
# 8B80
# nah
# 8B8F
# nah
# 8DCL
# 8DP2
# 8DSH
# 8E0D
# 8EN9

# %%
from pyrosetta import *
from pyrosetta.rosetta import *
from pyrosetta.teaching import *

from pyrosetta.rosetta.protocols.carbohydrates import *
from pyrosetta.rosetta.core.select.residue_selector import *
from pyrosetta.rosetta.core.simple_metrics.metrics import *
from pyrosetta.rosetta.core.simple_metrics.composite_metrics import *
from pyrosetta.rosetta.core.simple_metrics.per_residue_metrics import *


from pyrosetta import *
from pyrosetta.teaching import *
from pyrosetta.rosetta.core.pose import *
import os
import shutil
from data_utils import done_data_recorder

init('-include_sugars  -ideal_sugars -ignore_unrecognized_res -renumber_pdb -ignore_zero_occupancy false  -alternate_3_letter_codes pdb_sugar -maintain_links -auto_detect_glycan_connections  -mute all')
# Out:
# PyRosetta-4 2021 [Rosetta PyRosetta4.Release.python38.mac 2021.36+release.57ac713a6e1d8ce6f60269b3988b1adac1d96fc6 2021-09-10T13:50:04] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.

# %%
input_dir = "./temp_dir/" #Enter input directory here
out_dir = "./temp_dir/out/" #If not using default graph model, input your graph model here
graph_model_dir = "./capsif_g/models_DL/cb_model.pth.tar" #If not using default graph model, input your CAPSIF:G model here
voxel_model_dir = "./capsif_v/models_DL/my_checkpoint_best_36_2A_CACB_vector_coord_I_clean_data.pth.tar" #If not using default CAPSIF:V model, input your graph model here
make_pdb = True; #Output the files with the B factor as 99.99 for when bound

# %% [markdown]
# ### Initialize Directories and libraries ###

# %%
#Safety check with rerunning things to switch back to the native absolute path :)
import os
native_dir = os.path.abspath('.') + "/"
input_dir = os.path.abspath(input_dir) + "/"
out_dir = os.path.abspath(out_dir)
graph_model_dir = os.path.abspath(graph_model_dir)
voxel_model_dir = os.path.abspath(voxel_model_dir)

# %%
print(native_dir)
# Out:
# /Users/scanner1/Downloads/capsif_repo/CAPSIF/

# %%
import sys

os.chdir(native_dir)

os.chdir("./capsif_v/")
#CAPSIF:V requirements
sys.path.append("./capsif_v/")
from capsif_v.utils import xyz_to_rotate_to_voxelize_to_translate
from capsif_v.prediction_utils import load_model as load_voxel_model, command_run
from data_preparation.pdb_2_interaction_file_converter import pdb_to_interaction_file as capsif_v_pdb_preprocess
os.chdir('../')
sys.path.append('../')

os.chdir("./capsif_g/")
sys.path.append("./capsif_g/")
from capsif_g.dataset import load_predictor_model as load_graph_model
from notebook_library import download_pdb, predict_for_voxel as predict_voxel, visualize, preprocess_graph, predict_for_graph as predict_graph, output_structure_bfactor_biopython_BOTH as output_structure_bfactor
os.chdir("../")
sys.path.append("../")

import numpy as np
import time
import torch


#Directory information!
input_dir = os.path.abspath(input_dir) + "/"
out_dir = os.path.abspath(out_dir) + "/"

# %% [markdown]
# ### Initialize Models ###

# %%
#Initialize Models

#Run only on CAPSIF:V files
# Initialize pdb into npz file for reading
#if you fail to get outputs, feel free to mess around with the values :)
pdb_npz_file_reader = xyz_to_rotate_to_voxelize_to_translate()
pdb_npz_file_reader.max_rotation_plus_minus = 0
pdb_npz_file_reader.max_pixel_translate_per_axis = 0
pdb_npz_file_reader.use_res_index = 1
pdb_npz_file_reader.layers_use = 29
pdb_npz_file_reader.layer_29_type = 2
pdb_npz_file_reader.cube_start_points = 1
pdb_npz_file_reader.crop_extra_edge = 0
pdb_npz_file_reader.cube_start_points = 1

#load model
os.chdir('capsif_v')
start_time = time.time()
model = load_voxel_model(2,2,dir=voxel_model_dir)
model_time = time.time()
print("CAPSIF:V Model load time: ","%5.1f " % (model_time -start_time), "seconds.\n")
os.chdir(native_dir)

#Initialize Graph
start_time = time.time()
graph_model = load_graph_model(graph_model_dir)
model_time = time.time()
print("CAPSIF:G Model load time: ","%5.3f " % (model_time -start_time), "seconds.")
# Out:
# Using /Users/scanner1/Downloads/capsif_repo/CAPSIF/capsif_v/models_DL/my_checkpoint_best_36_2A_CACB_vector_coord_I_clean_data.pth.tar
# => Loading checkpoint
# CAPSIF:V Model load time:    1.4  seconds.
#
# CAPSIF:G Model load time:  0.061  seconds.

# %% [markdown]
# ## Run Prediction ##

# %%
os.chdir('..')
print(input_dir)
# Out:
# /Users/scanner1/Downloads/capsif_repo/CAPSIF/temp_dir/

# %%
ls = os.listdir(input_dir);

out_file = open(out_dir + 'capsif_predictions.txt','w+')
out_file.write("PDB_Name,CAPSIF:V_predictions,CAPSIF:G_predictions\n")

#for pdb_file in ls:
for rcsb in ls:
    
    #if '.pdb' in pdb_file:
    if "_" in rcsb:
    
        #rcsb = '1bag'
        print(rcsb)
        os.chdir(native_dir)
        pdb_file = input_dir+ rcsb
        #pdb_file = download_pdb(rcsb,data_dir='./sample_dir',assembly=0)
        pdb_file = os.path.abspath(pdb_file)    
        
        os.chdir('capsif_v')
        print('Currently treating: ' + pdb_file)
                
        try:
        #if True:
            f = capsif_v_pdb_preprocess( pdb_file, './',
                                                0, verbose=1,
                                                use_glycan=1)
            f.carb_aa_distance_calc_and_save = 1
            f.save_data =0
            s,x = f.run_me()

            if len(x) <= 1:
                if len(x) == 0:
                    print("Can not read pdb file! Not a protein data.")

                if x[0] == -1:
                    print("PyRosetta could not read glycan!")
                    print("Check PDB file (ring glycan, clashes etc.)!")
                    print("or use restart the code and run 'load_glycan_off' flag. Dice will be 0")
                #continue

            #print(s,x)
            #CAPSIF:V Predictions
            proteins,masks = pdb_npz_file_reader.apply(x,s)
            d,voxel_res,py_com,pred_vox=predict_voxel(torch.from_numpy(proteins), torch.from_numpy(masks), model,  2 ,save_npz=0)
            os.chdir(native_dir)
        except:
            continue;
        
        #print(d)
        
        #CAPSIF:G Predictions
        #os.chdir('capsif_g/')
        #graph_dice, graph_results, graph_res = predict_graph(input_dir + pdb_file,model=graph_model)
        #os.chdir(native_dir)
        

        #if make_pdb :
        #    output_structure_bfactor(in_file=input_dir + pdb_file,res_v=voxel_res,res_g=graph_res,out_file=out_dir + pdb_file[:pdb_file.index('.')] + "_predictions.pdb")
        
        #out_file.write(pdb_file + " : " + voxel_res + '\n')
        
        out_file.write(rcsb + " : " + str(d.item()) + "\n")
        #break

out_file.close()

print("CAPSIF Predictions Finished!")
print("Outputted to: " + out_dir + ".txt")
# Out:
# 7NHO_ADF.pdb
# Currently treating: /Users/scanner1/Downloads/capsif_repo/CAPSIF/temp_dir/7NHO_ADF.pdb
# PyRosetta-4 2021 [Rosetta PyRosetta4.Release.python38.mac 2021.36+release.57ac713a6e1d8ce6f60269b3988b1adac1d96fc6 2021-09-10T13:50:04] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# Starting pdb file: 7NHO_ADF
# /Users/scanner1/Downloads/capsif_repo/CAPSIF/capsif_v /Users/scanner1/Downloads/capsif_repo/CAPSIF/temp_dir/7NHO_ADF.pdb
# currently treating: 7NHO_ADF
# 7LXI_A.pdb
# Currently treating: /Users/scanner1/Downloads/capsif_repo/CAPSIF/temp_dir/7LXI_A.pdb
# PyRosetta-4 2021 [Rosetta PyRosetta4.Release.python38.mac 2021.36+release.57ac713a6e1d8ce6f60269b3988b1adac1d96fc6 2021-09-10T13:50:04] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# Starting pdb file: 7LXI_A
# /Users/scanner1/Downloads/capsif_repo/CAPSIF/capsif_v /Users/scanner1/Downloads/capsif_repo/CAPSIF/temp_dir/7LXI_A.pdb
# currently treating: 7LXI_A
# 7DSY_AB.pdb
# Currently treating: /Users/scanner1/Downloads/capsif_repo/CAPSIF/temp_dir/7DSY_AB.pdb
# PyRosetta-4 2021 [Rosetta PyRosetta4.Release.python38.mac 2021.36+release.57ac713a6e1d8ce6f60269b3988b1adac1d96fc6 2021-09-10T13:50:04] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# Starting pdb file: 7DSY_AB
# /Users/scanner1/Downloads/capsif_repo/CAPSIF/capsif_v /Users/scanner1/Downloads/capsif_repo/CAPSIF/temp_dir/7DSY_AB.pdb
# currently treating: 7DSY_AB
# 7NCZ_A.pdb
# Currently treating: /Users/scanner1/Downloads/capsif_repo/CAPSIF/temp_dir/7NCZ_A.pdb
# PyRosetta-4 2021 [Rosetta PyRosetta4.Release.python38.mac 2021.36+release.57ac713a6e1d8ce6f60269b3988b1adac1d96fc6 2021-09-10T13:50:04] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# Starting pdb file: 7NCZ_A
# /Users/scanner1/Downloads/capsif_repo/CAPSIF/capsif_v /Users/scanner1/Downloads/capsif_repo/CAPSIF/temp_dir/7NCZ_A.pdb
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-5f82c246079a> in <module>
#      23         #if True:
# ---> 24             f = capsif_v_pdb_preprocess( pdb_file, './',
#      25                                                 0, verbose=1,
#
# ~/Downloads/capsif_repo/CAPSIF/data_preparation/pdb_2_interaction_file_converter.py in __init__(self, prot_file, out_dir, check_done, verbose, use_glycan)
#      47         #try:
# ---> 48         self.pose_native = pose_from_pdb(prot_file)
#      49         self.pose_use = self.pose_native.clone()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyrosetta-2021.36+release.57ac713a6e1-py3.8-macosx-10.9-x86_64.egg/pyrosetta/io/__init__.py in pose_from_pdb(filename)
#      19 def pose_from_pdb(filename):
# ---> 20     return pose_from_file(filename)
#      21
#
# RuntimeError:
#
# File: /Volumes/MacintoshHD3/benchmark/W.fujii.release/rosetta.Fujii.release/_commits_/main/source/src/core/conformation/Conformation.cc:2316
# [ ERROR ] UtilityExitException
# ERROR:
#
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5f82c246079a> in <module>
#      22         try:
#      23         #if True:
# ---> 24             f = capsif_v_pdb_preprocess( pdb_file, './',
#      25                                                 0, verbose=1,
#      26                                                 use_glycan=1)
#
# KeyboardInterrupt:

# %%
ls = os.listdir('./temp_dir')

# %%
os.getcwd()
# Out:
# '/Users/scanner1/Downloads/capsif_repo/CAPSIF/capsif_v'
